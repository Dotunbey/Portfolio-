# %%
pwd
# Out:
# 'C:\\Users\\Oluwasomidotun'

# %%
from platform import python_version
print (python_version())
# Out:
# 3.11.5

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
train = pd.read_csv('train.csv')
train.head(10)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
# 5   6          50       RL         85.0    14115   Pave   NaN      IR1
# 6   7          20       RL         75.0    10084   Pave   NaN      Reg
# 7   8          60       RL          NaN    10382   Pave   NaN      IR1
# 8   9          50       RM         51.0     6120   Pave   NaN      Reg
# 9  10         190       RL         50.0     7420   Pave   NaN      Reg
#
#   LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
train.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %% [markdown]
# # DATA CLEANING

# %%
plt.figure(figsize=(12,8))
sns.heatmap(train.isnull())
#FINDING MISSING VALUES
# Out:
# <AxesSubplot: >

# %%
for x in train.columns:
    y = train[x].isnull().sum()
    if y > 0:
        print (x,y)
# Out:
# LotFrontage 259
# Alley 1369
# MasVnrType 8
# MasVnrArea 8
# BsmtQual 37
# BsmtCond 37
# BsmtExposure 38
# BsmtFinType1 37
# BsmtFinType2 38
# Electrical 1
# FireplaceQu 690
# GarageType 81
# GarageYrBlt 81
# GarageFinish 81
# GarageQual 81
# GarageCond 81
# PoolQC 1453
# Fence 1179
# MiscFeature 1406

# %%
train[train['Electrical'].isnull()]

train['Fence']=train['Fence'].fillna('None')
#None - No Fence

train['MiscFeature']=train['MiscFeature'].fillna('None')
#None - No MiscFeature

train['GarageCond']=train['GarageCond'].fillna('None')
#None - No Garage

train['GarageFinish']=train['GarageFinish'].fillna('None')
#None - No Garage

train['GarageQual']=train['GarageQual'].fillna('None')
#None - No Garage

train['GarageYrBlt']=train['GarageYrBlt'].fillna(0)
#None - No Garage

train['GarageType']=train['GarageType'].fillna('None')
#None - No GarageType

train['FireplaceQu']=train['FireplaceQu'].fillna('None')
#None - No Fireplace

train['Alley']=train['Alley'].fillna('None')
#None - No alley

train['MasVnrType']=train['MasVnrType'].fillna('None')
#None - No Masonry veneer 


train['PoolQC']=train['PoolQC'].fillna('None')
#None - No pool

train['BsmtQual']=train['BsmtQual'].fillna('None')
#None - No basement

train['BsmtCond']=train['BsmtCond'].fillna('None')
#None - No basement

train['BsmtCond']=train['BsmtCond'].fillna('None')
#NoB - No basement

train['BsmtExposure']=train['BsmtExposure'].fillna('None')

train['BsmtFinType1']=train['BsmtFinType1'].fillna('None')

train['BsmtFinType2']=train['BsmtFinType2'].fillna('None')

# %% [markdown]
# tra = train.drop(['MSZoning','Street','Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle','RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType','BsmtFinType2','Heating',
#        'HeatingQC', 'CentralAir', 'Electrical','KitchenQual','Functional','FireplaceQu', 'GarageType','GarageFinish','GarageQual',
#        'GarageCond', 'PavedDrive','PoolQC',
#        'Fence', 'MiscFeature','SaleType',
#        'SaleCondition','ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1'],axis=1)

# %%
for x in train.columns:
    y = train[x].isnull().sum()
    if y > 0:
        print (x,y)
# Out:
# LotFrontage 259
# MasVnrArea 8
# Electrical 1

# %%
train[train['Electrical'].isnull()]['Electrical']
# Out:
# 1379    NaN
# Name: Electrical, dtype: object

# %%
#we can safely drop th
train.drop(1379,axis=0,inplace=True)

# %%
sns.set_style('darkgrid')
plt.figure(figsize=(12,8))
sns.boxplot(train['LotFrontage'])
# Out:
# <AxesSubplot: >

# %%
sns.displot(train['SalePrice'],kde=True,bins=20)

# %%
train['LotFrontage'].mode()
# Out:
# 0    60.0
# Name: LotFrontage, dtype: float64

# %%
train['LotFrontage']=train['LotFrontage'].fillna(60.0)

# %%
plt.figure(figsize=(12,7))
sns.boxplot(x='MasVnrType',y='MasVnrArea',data=train,palette='winter')
# Out:
# <AxesSubplot: xlabel='MasVnrType', ylabel='MasVnrArea'>

# %% [markdown]
# since all the null values have no MasVnr we fill all NaN with 0

# %%
train['MasVnrArea']=train['MasVnrArea'].fillna(0)

# %%
train['GarageYrBlt'].value_counts()
# Out:
# 0.0       81
# 2005.0    65
# 2006.0    59
# 2004.0    53
# 2003.0    50
#           ..
# 1927.0     1
# 1900.0     1
# 1906.0     1
# 1908.0     1
# 1933.0     1
# Name: GarageYrBlt, Length: 98, dtype: int64

# %% [markdown]
# most garage were built from 2003 to 2007

# %%
train['YearBuilt'].value_counts()
# Out:
# 2006    66
# 2005    64
# 2004    54
# 2007    49
# 2003    45
#         ..
# 1875     1
# 1911     1
# 1917     1
# 1872     1
# 1905     1
# Name: YearBuilt, Length: 112, dtype: int64

# %% [markdown]
# the garage is most likely built the year the house was built

# %%
#drop the id
train.drop('Id',axis=1,inplace=True)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1459 entries, 0 to 1459
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1459 non-null   int64
#  1   MSZoning       1459 non-null   object
#  2   LotFrontage    1459 non-null   float64
#  3   LotArea        1459 non-null   int64
#  4   Street         1459 non-null   object
#  5   Alley          1459 non-null   object
#  6   LotShape       1459 non-null   object
#  7   LandContour    1459 non-null   object
#  8   Utilities      1459 non-null   object
#  9   LotConfig      1459 non-null   object
#  10  LandSlope      1459 non-null   object
#  11  Neighborhood   1459 non-null   object
#  12  Condition1     1459 non-null   object
#  13  Condition2     1459 non-null   object
#  14  BldgType       1459 non-null   object
#  15  HouseStyle     1459 non-null   object
#  16  OverallQual    1459 non-null   int64
# ...

# %%
#grabbing all the objects to classify them
t=train[['Street', 'Alley',
       'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope','GarageQual', 'GarageCond',
       'PavedDrive', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle','MSZoning','RoofStyle',
       'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType','ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
       'BsmtExposure', 'BsmtFinType1','BsmtFinType2','Heating', 'HeatingQC','KitchenQual','Functional',
       'CentralAir', 'Electrical','FireplaceQu', 'GarageType','GarageFinish','PoolQC', 'Fence', 'MiscFeature', 
       'SaleType', 'SaleCondition']]


from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

for x in t.columns:
    t[x]=le.fit_transform(t[x])
# Out:
# C:\Users\Oluwasomidotun\AppData\Local\Temp\ipykernel_1272\244940462.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   t[x]=le.fit_transform(t[x])
# C:\Users\Oluwasomidotun\AppData\Local\Temp\ipykernel_1272\244940462.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   t[x]=le.fit_transform(t[x])
# C:\Users\Oluwasomidotun\AppData\Local\Temp\ipykernel_1272\244940462.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
train.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          60       RL         65.0     8450   Pave  None      Reg
# 1          20       RL         80.0     9600   Pave  None      Reg
# 2          60       RL         68.0    11250   Pave  None      IR1
# 3          70       RL         60.0     9550   Pave  None      IR1
# 4          60       RL         84.0    14260   Pave  None      IR1
#
#   LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# 0         Lvl    AllPub    Inside  ...        0   None  None        None
# 1         Lvl    AllPub       FR2  ...        0   None  None        None
# 2         Lvl    AllPub    Inside  ...        0   None  None        None
# 3         Lvl    AllPub    Corner  ...        0   None  None        None
# 4         Lvl    AllPub       FR2  ...        0   None  None        None
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# 0       0      2    2008        WD         Normal     208500
# ...

# %%
X = train.drop('SalePrice',axis=1)
y= train['SalePrice']

# %%
train.columns
# Out:
# Index(['MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street', 'Alley',
#        'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
#        'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea',
#        'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
#        'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType', 'GarageYrBlt',
# ...

# %%
train[['Street', 'Alley',
       'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope','GarageQual', 'GarageCond',
       'PavedDrive', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle','MSZoning','RoofStyle',
       'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType','ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
       'BsmtExposure', 'BsmtFinType1','BsmtFinType2','Heating', 'HeatingQC','KitchenQual','Functional',
       'CentralAir', 'Electrical','FireplaceQu', 'GarageType','GarageFinish','PoolQC', 'Fence', 'MiscFeature', 
       'SaleType', 'SaleCondition']]=t

# %%
sns.displot(data=train['SalePrice'])

# %%
sns.scatterplot(data=train, x='YearBuilt',y='SalePrice')
# Out:
# <AxesSubplot: xlabel='YearBuilt', ylabel='SalePrice'>

# %%
sns.scatterplot(data=train, x='YearBuilt',y='SalePrice',hue='Neighborhood')
# Out:
# <AxesSubplot: xlabel='YearBuilt', ylabel='SalePrice'>

# %%
train.head()
# Out:
#    MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  LotShape  \
# 0          60         3         65.0     8450       1      1         3
# 1          20         3         80.0     9600       1      1         3
# 2          60         3         68.0    11250       1      1         0
# 3          70         3         60.0     9550       1      1         0
# 4          60         3         84.0    14260       1      1         0
#
#    LandContour  Utilities  LotConfig  ...  PoolArea  PoolQC  Fence  \
# 0            3          0          4  ...         0       3      4
# 1            3          0          2  ...         0       3      4
# 2            3          0          4  ...         0       3      4
# 3            3          0          0  ...         0       3      4
# 4            3          0          2  ...         0       3      4
#
#    MiscFeature  MiscVal  MoSold  YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
train.describe()
# Out:
#         MSSubClass     MSZoning  LotFrontage        LotArea       Street  \
# count  1459.000000  1459.000000  1459.000000    1459.000000  1459.000000
# mean     56.881426     3.028787    68.263879   10517.363948     0.995888
# std      42.310746     0.632234    22.363676    9984.666267     0.064018
# min      20.000000     0.000000    21.000000    1300.000000     0.000000
# 25%      20.000000     3.000000    60.000000    7549.000000     1.000000
# 50%      50.000000     3.000000    63.000000    9477.000000     1.000000
# 75%      70.000000     3.000000    79.000000   11603.000000     1.000000
# max     190.000000     4.000000   313.000000  215245.000000     1.000000
#
#              Alley     LotShape  LandContour    Utilities    LotConfig  ...  \
# count  1459.000000  1459.000000  1459.000000  1459.000000  1459.000000  ...
# mean      0.993831     1.941741     2.777245     0.000685     3.018506  ...
# std       0.249752     1.409367     0.707885     0.026180     1.622987  ...
# ...

# %%
train.corr()
# Out:
#                MSSubClass  MSZoning  LotFrontage   LotArea    Street  \
# MSSubClass       1.000000  0.035921    -0.349236 -0.139766 -0.024995
# MSZoning         0.035921  1.000000    -0.101145 -0.034454  0.087656
# LotFrontage     -0.349236 -0.101145     1.000000  0.281299 -0.037088
# LotArea         -0.139766 -0.034454     0.281299  1.000000 -0.197128
# Street          -0.024995  0.087656    -0.037088 -0.197128  1.000000
# ...                   ...       ...          ...       ...       ...
# MoSold          -0.013404 -0.031514     0.012857  0.001179  0.003712
# YrSold          -0.021461 -0.020623     0.003001 -0.014254 -0.025050
# SaleType         0.012348  0.097450    -0.035821  0.012310  0.014326
# SaleCondition   -0.025021  0.009500     0.061365  0.034181  0.006055
# SalePrice       -0.084230 -0.166879     0.329253  0.263837  0.041043
#
#                   Alley  LotShape  LandContour  Utilities  LotConfig  ...  \
# ...

# %%
import torch

from torch import nn

import torch.nn.functional as f

import torch.optim as optim

from torch.utils.data import TensorDataset, DataLoader

import torchmetrics

train.shape

import datetime

datetime.datetime.now().year
# Out:
# 2024

# %%
train['total years']= datetime.datetime.now().year-train['YearBuilt']

# %%
train['total years']
# Out:
# 0        21
# 1        48
# 2        23
# 3       109
# 4        24
#        ...
# 1455     25
# 1456     46
# 1457     83
# 1458     74
# 1459     59
# Name: total years, Length: 1459, dtype: int64

# %%
import sweetviz
rep = sweetviz.analyze(train,target_feat='SalePrice')
rep.show_html()
# Out:
#                                              |                                             | [  0%]   00:00 ->…
# Report SWEETVIZ_REPORT.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
X=train.drop('SalePrice',axis = 1)
y=   train['SalePrice']
bestfeat = SelectKBest(score_func=chi2,k=20)
fit = bestfeat.fit(X,y)

# %%
dfscores=pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(X.columns)
featscore= pd.concat([dfcolumns,dfscores],axis=1)
featscore.columns = ['feature','scores']
featscore
# Out:
#           feature        scores
# 0      MSSubClass  1.929157e+04
# 1        MSZoning  1.138021e+02
# 2     LotFrontage  5.319293e+03
# 3         LotArea  1.011442e+07
# 4          Street  3.650595e+00
# ..            ...           ...
# 74        MiscVal  6.249006e+06
# 75         MoSold  7.430146e+02
# 76         YrSold  6.037014e-01
# 77       SaleType  1.874471e+02
# 78  SaleCondition  2.125815e+02
#
# [79 rows x 2 columns]

# %%
feat=featscore.nlargest(51,'scores')
feat
# Out:
#           feature        scores
# 3         LotArea  1.011442e+07
# 74        MiscVal  6.249006e+06
# 43       2ndFlrSF  4.649813e+05
# 33     BsmtFinSF1  3.994498e+05
# 70       PoolArea  3.832987e+05
# 35     BsmtFinSF2  3.685835e+05
# 25     MasVnrArea  2.878933e+05
# 36      BsmtUnfSF  2.747139e+05
# 44   LowQualFinSF  2.447074e+05
# 45      GrLivArea  1.968564e+05
# 37    TotalBsmtSF  1.744388e+05
# 68      3SsnPorch  1.548265e+05
# 69    ScreenPorch  1.367470e+05
# 65     WoodDeckSF  1.300078e+05
# 42       1stFlrSF  1.237504e+05
# 67  EnclosedPorch  9.879688e+04
# 61     GarageArea  9.617574e+04
# 58    GarageYrBlt  8.297190e+04
# 66    OpenPorchSF  7.433003e+04
# 0      MSSubClass  1.929157e+04
# 2     LotFrontage  5.319293e+03
# 11   Neighborhood  2.199226e+03
# 14       BldgType  1.949648e+03
# 39      HeatingQC  1.485045e+03
# 57     GarageType  1.265003e+03
# 32   BsmtFinType1  1.036247e+03
# 10      LandSlope  8.891220e+02
# 23    Exterior2nd  8.112374e+02
# ...

# %%
k = []
for i in feat['feature']:
    k.append(i)

k.append('SalePrice')
train[k]
# Out:
#       LotArea  MiscVal  2ndFlrSF  BsmtFinSF1  PoolArea  BsmtFinSF2  \
# 0        8450        0       854         706         0           0
# 1        9600        0         0         978         0           0
# 2       11250        0       866         486         0           0
# 3        9550        0       756         216         0           0
# 4       14260        0      1053         655         0           0
# ...       ...      ...       ...         ...       ...         ...
# 1455     7917        0       694           0         0           0
# 1456    13175        0         0         790         0         163
# 1457     9042     2500      1152         275         0           0
# 1458     9717        0         0          49         0        1029
# 1459     9937        0         0         830         0         290
#
#       MasVnrArea  BsmtUnfSF  LowQualFinSF  GrLivArea  ...  TotRmsAbvGrd  \
# 0          196.0        150             0       1710  ...             8
# ...

# %%
from pycaret.regression import*

# %%
setup(train[k],target='SalePrice')
# Out:
# <style type="text/css">
# #T_086c8_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_086c8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_086c8_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_086c8_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_086c8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_086c8_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_086c8_row0_col1" class="data row0 col1" >2498</td>
#     </tr>
#     <tr>
#       <th id="T_086c8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_086c8_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_086c8_row1_col1" class="data row1 col1" >SalePrice</td>
#     </tr>
#     <tr>
#       <th id="T_086c8_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
bestmodel = compare_models()
# Out:
# <style type="text/css">
# #T_de3b8 th {
#   text-align: left;
# }
# ...

# %%
tuned_model = tune_model(bestmodel)
# Out:
# <style type="text/css">
# #T_cf8eb_row10_col0, #T_cf8eb_row10_col1, #T_cf8eb_row10_col2, #T_cf8eb_row10_col3, #T_cf8eb_row10_col4, #T_cf8eb_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_cf8eb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cf8eb_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_cf8eb_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_cf8eb_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_cf8eb_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_cf8eb_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_cf8eb_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
plot_model(tuned_model,plot='error')

# %%
plot_model(tuned_model,plot='feature')

# %%
evaluate_model(tuned_model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
final_model = finalize_model(tuned_model)

# %%
test = pd.read_csv('test.csv')

# %%
test
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1     1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2     1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3     1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4     1465         120       RL         43.0     5005   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
# ...

# %%
for x in test.columns:
    y = test[x].isnull().sum()
    if y > 0:
        print (x,y)
# Out:
# MSZoning 4
# LotFrontage 227
# Alley 1352
# Utilities 2
# Exterior1st 1
# Exterior2nd 1
# MasVnrType 16
# MasVnrArea 15
# BsmtQual 44
# BsmtCond 45
# BsmtExposure 44
# BsmtFinType1 42
# BsmtFinSF1 1
# BsmtFinType2 42
# BsmtFinSF2 1
# BsmtUnfSF 1
# TotalBsmtSF 1
# BsmtFullBath 2
# BsmtHalfBath 2
# KitchenQual 1
# Functional 2
# FireplaceQu 730
# GarageType 76
# GarageYrBlt 78
# GarageFinish 78
# GarageCars 1
# GarageArea 1
# GarageQual 78
# GarageCond 78
# PoolQC 1456
# Fence 1169
# MiscFeature 1408
# SaleType 1

# %%
test['TotalBsmtSF'].mode()
# Out:
# 0    0.0
# Name: TotalBsmtSF, dtype: float64

# %%
test['BsmtUnfSF']=test['BsmtUnfSF'].fillna(0)

# %%
test['Exterior1st']=test['Exterior1st'].fillna('VinylSd')
test['Exterior2nd']=test['Exterior2nd'].fillna('VinylSd')

# %%
test['Utilities']=test['Utilities'].fillna('AllPub')

# %%
test['MSZoning']=test['MSZoning'].fillna('None')
#None - No Fence

# %%
test[test['Electrical'].isnull()]

test['Fence']=test['Fence'].fillna('None')
#None - No Fence

test['MiscFeature']=test['MiscFeature'].fillna('None')
#None - No MiscFeature

test['GarageCond']=test['GarageCond'].fillna('None')
#None - No Garage

test['GarageFinish']=test['GarageFinish'].fillna('None')
#None - No Garage

test['GarageQual']=test['GarageQual'].fillna('None')
#None - No Garage

test['GarageYrBlt']=test['GarageYrBlt'].fillna(0)
#None - No Garage

test['GarageType']=test['GarageType'].fillna('None')
#None - No GarageType

test['FireplaceQu']=test['FireplaceQu'].fillna('None')
#None - No Fireplace

test['Alley']=test['Alley'].fillna('None')
#None - No alley

test['MasVnrType']=test['MasVnrType'].fillna('None')
#None - No Masonry veneer 


test['PoolQC']=test['PoolQC'].fillna('None')
#None - No pool

test['BsmtQual']=test['BsmtQual'].fillna('None')
#None - No basement

test['BsmtCond']=test['BsmtCond'].fillna('None')
#None - No basement

test['BsmtCond']=test['BsmtCond'].fillna('None')
#NoB - No basement

test['BsmtExposure']=test['BsmtExposure'].fillna('None')

test['BsmtFinType1']=test['BsmtFinType1'].fillna('None')

test['BsmtFinType2']=test['BsmtFinType2'].fillna('None')

# %%
test['LotFrontage'].mode()
# Out:
# 0    60.0
# Name: LotFrontage, dtype: float64

# %%
test['LotFrontage']=test['LotFrontage'].fillna(60.0)

# %%
test['MasVnrArea'].fillna(1,inplace= True)

# %%
for x in test.columns:
    y = test[x].isnull().sum()
    if y > 0:
         test[x].fillna(test[x].mode()[0],inplace=True)

# %%
test['BsmtFinSF1'].fillna(test['BsmtFinSF1'].mean(),inplace=True)
test['BsmtFinSF2'].fillna(test['BsmtFinSF2'].mean(),inplace=True)

# %%
train['BsmtUnfSF'].fillna(test['BsmtUnfSF'].mean(),inplace=True)

# %%
#grabbing all the objects to classify them
s=test[['Street', 'Alley',
       'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope','GarageQual', 'GarageCond',
       'PavedDrive', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle','MSZoning','RoofStyle',
       'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType','ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
       'BsmtExposure', 'BsmtFinType1','BsmtFinType2','Heating', 'HeatingQC','KitchenQual','Functional',
       'CentralAir', 'Electrical','FireplaceQu', 'GarageType','GarageFinish','PoolQC', 'Fence', 'MiscFeature', 
       'SaleType', 'SaleCondition']]


from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

for x in t.columns:
    s[x]=le.fit_transform(s[x])

# %%
test[['Street', 'Alley',
       'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope','GarageQual', 'GarageCond',
       'PavedDrive', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle','MSZoning','RoofStyle',
       'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType','ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
       'BsmtExposure', 'BsmtFinType1','BsmtFinType2','Heating', 'HeatingQC','KitchenQual','Functional',
       'CentralAir', 'Electrical','FireplaceQu', 'GarageType','GarageFinish','PoolQC', 'Fence', 'MiscFeature', 
       'SaleType', 'SaleCondition']]=s

# %%
predict=predict_model(final_model,data=test[k])

# %%
predict['prediction_label']
# Out:
# 0       124171.651027
# 1       163995.361375
# 2       174151.082103
# 3       185369.373079
# 4       188388.209086
#             ...
# 1454     73716.567232
# 1455     82436.858869
# 1456    151427.172485
# 1457    113571.490671
# 1458    211596.798867
# Name: prediction_label, Length: 1459, dtype: float64

# %%
test['Id']
# Out:
# 0       1461
# 1       1462
# 2       1463
# 3       1464
# 4       1465
#         ...
# 1454    2915
# 1455    2916
# 1456    2917
# 1457    2918
# 1458    2919
# Name: Id, Length: 1459, dtype: int64

# %%
output = pd.DataFrame({'Id' : test['Id'],'SalePrice' : predict['prediction_label']})

# %%
output.head()
# Out:
#      Id      SalePrice
# 0  1461  124171.651027
# 1  1462  163995.361375
# 2  1463  174151.082103
# 3  1464  185369.373079
# 4  1465  188388.209086

# %%
output.to_csv('salesprice1.csv',index=False)
